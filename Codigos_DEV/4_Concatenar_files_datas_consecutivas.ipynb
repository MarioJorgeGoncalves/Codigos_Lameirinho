# %% [markdown]
# ### BIBLIOTECAS

# %%
import os
import pandas as pd
import numpy as np
import glob
import matplotlib as plt
import matplotlib.pyplot as plt

# %% [markdown]
# ### CONCATENAR
#
# ### dados_lameirinho_P 05_02_2024_sem_missing_values                            29/01/2024 09:33:08     05/02/2024 09:07:55
# ### dados_lameirinho_5_fev_14_fev_sem_missing_values                            05/02/2024 09:19:12     14/02/2024 09:10:49
# ### dados_lameirinho_P_19_02_2024_sem_missing_values                            14/02/2024 09:14:54     19/02/2024 09:56:16
# ### dados_lameirinho_26_02_2024_sem_missing_values                              19/02/2024 09:57:07     26/02/2024 09:09:25
# ### dados_lameirinho_CP_26_02_04_03_2024_sem_missing_values                     26/02/2024 09:09:26     04/03/2024 16:25:09
# ### dados_lameirinho_CP_11_03_2024_sem_missing_values                           04/03/2024 16:25:10     11/03/2024 19:23:52
# ### dados_lameirinho_11_03_2024_sem_missing_values                              11/03/2024 19:26:32     18/03/2024 16:10:06
# ### dados_lameirinho_CP_25_03_2024_sem_missing_values                           18/03/2024 16:11:23     25/03/2024 15:09:04
# ### dados_lameirinho_P_25_3_08_04_2024_NEW_sem_missing_values                   25/03/2024 15:10:51     08/04/2024 09:39:40
# ### dados_lameirinho_8_4_15_04_2024_NEW_sem_missing_values                      08/04/2024 09:41:18     15/04/2024 14:03:04
# ### dados_lameirinho_15_04_22_04_2024_NEW_sem_missing_values                    15/04/2024 14:08:41     22/04/2024 14:51:10
# ### dados_lameirinho_22_04_29_04_2024_NEW_sem_missing_values                    22/04/2024 14:55:12     29/04/2024 09:06:05
# ### dados_lameirinho_CP_29_04_06_05_2024_sem_missing_values                     29/04/2024 18:30:36     06/05/2024 17:30:23
# ### dados_lameirinho_06_05_13_05_2024_sem_excesso_original_sem_missing_values   06/05/2024 17:30:24     13/05/2024 10:22:15
# ### dados_lameirinho_E_CP_13_05_20_05_sem_missing_values                        13/05/2024 10:24:12     20/05/2024 10:46:47

# %%
caminho_arquivos_pkl_1 = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_com_series_temporais_regularizadas\dados_lameirinho_P 05_02_2024_sem_missing_values_com_serie_regularizada_1S.pkl'
df1 = pd.read_pickle(caminho_arquivos_pkl_1)
caminho_arquivos_pkl_2 = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_com_series_temporais_regularizadas\dados_lameirinho_5_fev_14_fev_sem_missing_values_com_serie_regularizada_1S.pkl'
df2 = pd.read_pickle(caminho_arquivos_pkl_2)
caminho_arquivos_pkl_3 = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_com_series_temporais_regularizadas\dados_lameirinho_P_19_02_2024_sem_missing_values_com_serie_regularizada_1S.pkl'
df3 = pd.read_pickle(caminho_arquivos_pkl_3)
caminho_arquivos_pkl_4 = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_com_series_temporais_regularizadas\dados_lameirinho_26_02_2024_sem_missing_values_com_serie_regularizada_1S.pkl'
df4 = pd.read_pickle(caminho_arquivos_pkl_4)
caminho_arquivos_pkl_5 = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_com_series_temporais_regularizadas\dados_lameirinho_CP_26_02_04_03_2024_sem_missing_values_com_serie_regularizada_1S.pkl'
df5 = pd.read_pickle(caminho_arquivos_pkl_5)
caminho_arquivos_pkl_6 = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_com_series_temporais_regularizadas\dados_lameirinho_CP_11_03_2024_sem_missing_values_com_serie_regularizada_1S.pkl'
df6 = pd.read_pickle(caminho_arquivos_pkl_6)
caminho_arquivos_pkl_7 = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_com_series_temporais_regularizadas\dados_lameirinho_11_03_2024_sem_missing_values_com_serie_regularizada_1S.pkl'
df7 = pd.read_pickle(caminho_arquivos_pkl_7)
caminho_arquivos_pkl_8 = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_com_series_temporais_regularizadas\dados_lameirinho_CP_25_03_2024_sem_missing_values_com_serie_regularizada_1S.pkl'
df8 = pd.read_pickle(caminho_arquivos_pkl_8)
caminho_arquivos_pkl_9 = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_com_series_temporais_regularizadas\dados_lameirinho_P_25_3_08_04_2024_NEW_sem_missing_values_com_serie_regularizada_1S.pkl'
df9 = pd.read_pickle(caminho_arquivos_pkl_9)
caminho_arquivos_pkl_10 = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_com_series_temporais_regularizadas\dados_lameirinho_8_4_15_04_2024_NEW_sem_missing_values_com_serie_regularizada_1S.pkl'
df10 = pd.read_pickle(caminho_arquivos_pkl_10)
caminho_arquivos_pkl_11 = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_com_series_temporais_regularizadas\dados_lameirinho_15_04_22_04_2024_NEW_sem_missing_values_com_serie_regularizada_1S.pkl'
df11 = pd.read_pickle(caminho_arquivos_pkl_11)
caminho_arquivos_pkl_12 = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_com_series_temporais_regularizadas\dados_lameirinho_22_04_29_04_2024_NEW_sem_missing_values_com_serie_regularizada_1S.pkl'
df12 = pd.read_pickle(caminho_arquivos_pkl_12)
caminho_arquivos_pkl_13 = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_com_series_temporais_regularizadas\dados_lameirinho_CP_29_04_06_05_2024_sem_missing_values_com_serie_regularizada_1S.pkl'
df13 = pd.read_pickle(caminho_arquivos_pkl_13)
caminho_arquivos_pkl_14 = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_com_series_temporais_regularizadas\dados_lameirinho_06_05_13_05_2024_sem_excesso_original_sem_missing_values_com_serie_regularizada_1S.pkl'
df14 = pd.read_pickle(caminho_arquivos_pkl_14)
caminho_arquivos_pkl_15 = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_com_series_temporais_regularizadas\dados_lameirinho_E_CP_13_05_20_05_sem_missing_values_com_serie_regularizada_1S.pkl'
df15 = pd.read_pickle(caminho_arquivos_pkl_15)

# %%
# Eliminar a coluna 'datetime' do df14
df14 = df14.drop(columns=['datetime'])

# %%
# Concatenar df1 a df4
concatenado1 = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15])

# Imprimir os tamanhos dos DataFrames concatenados
print("Tamanho do DataFrame concatenado 1:", concatenado1.shape)
# Out:
# Tamanho do DataFrame concatenado 1: (10286020, 34)

# %%
# Remover Datetimes duplicados
concatenado1 = concatenado1[~concatenado1.index.duplicated(keep='first')]
# Out:
#                      G2_Gerador_Potência  G2_Oleo_Motor_Temp  \
# Datetime
# 2024-01-29 09:33:08               4374.0               80.90
# 2024-01-29 09:33:09               4389.5               80.90
# 2024-01-29 09:33:10               4405.0               80.90
# 2024-01-29 09:33:11               4410.0               80.95
# 2024-01-29 09:33:12               4415.0               81.00
# ...                                  ...                 ...
# 2024-05-20 10:46:43               4425.0               77.00
# 2024-05-20 10:46:44               4430.0               77.00
# 2024-05-20 10:46:45               4451.0               77.00
# 2024-05-20 10:46:46               4379.0               77.00
# 2024-05-20 10:46:47               4414.0               77.00
#
#                      G2_Oleo_Motor_Press  G2_Carga_Temperature  \
# Datetime
# 2024-01-29 09:33:08                4.070                 56.00
# 2024-01-29 09:33:09                4.065                 56.00
# ...

# %%
# Substituir todos os valores NaN por zero (aqueles valores que coloquei antes e depois para acertar as séries temporais)
concatenado1 = concatenado1.fillna(0)

# %%
# Adicionar coluna ID ao concatenado1
concatenado1['ID'] = range(1, len(concatenado1) + 1)

# %%
# Caminhos de saída para os arquivos concatenados
caminho_concatenado1_pkl = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_concatenados\files_29_01_and_20_05_concatenados.pkl'
#caminho_concatenado1_csv = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_concatenados\files_29_01_and_29_04_concatenados.csv'

# Salvar os DataFrames concatenados como arquivos pickle
concatenado1.to_pickle(caminho_concatenado1_pkl)

# Salvar os DataFrames concatenados como arquivos CSV
#concatenado1.to_csv(caminho_concatenado1_csv, index=True)

# %% [markdown]
# ### LEITURA CONCATENADO COM ID

# %%
Ficheiro_1_concatenado_29_01_20_05 = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_concatenados\files_29_01_and_20_05_concatenados.pkl'
concatenado_1 = pd.read_pickle(Ficheiro_1_concatenado_29_01_20_05)

# %%
concatenado_1.columns
# Out:
# Index(['G2_Gerador_Potência', 'G2_Oleo_Motor_Temp', 'G2_Oleo_Motor_Press',
#        'G2_Carga_Temperature', 'G2_Aumento_Pressão_Valvula_Real',
#        'G2_Gerador_Corrente_Média', 'G2_Gerador_Tensão_Média',
#        'G2_Gerador_Potência_Reativa', 'G2_Gerador_Potência_Aparente',
#        'G2_Gerador_frequencia', 'G2_Gerador_Fator_de_Potência',
#        'G2_Acelerador_Valv_Posição', 'G2_Jacket_Water_pressão',
#        'G2_Jacket_Water_Temp', 'G2_Cilindro_EX_GAS_TEMP_Média',
#        'g2_Turbocharger_Bypass_Posição', 'G2_Saída_Ativa_total',
#        'G2_Saída_Reativa_total', 'G2_LAMBDA_TECJET', 'G2_Gerador_Corrente_L1',
#        'G2_Gerador_Voltagem_L1_N', 'G2_Gerador_enrolamento_temp_L1',
#        'G2_Gerador_enrolamento_temp_L2', 'G2_Gerador_enrolamento_temp_L3',
#        'G2_Gerador_Extremidade_acionamento_rolamento',
#        'G2_Gerador_Bearing_nondriveend', 'G2_Gerador_Corrente_L2',
#        'G2_Gerador_Voltagem_L2_L3', 'G2_Gerador_Voltagem_L2_N',
# ...

# %%
# def interpolar_nans(concatenado_1, colunas_para_preencher):
#     """Interpola os NaNs em cada coluna com base nos valores imediatamente acima e abaixo."""
#     for coluna in colunas_para_preencher:
#         concatenado_1[coluna] = concatenado_1[coluna].interpolate(method='linear')
#     return concatenado_1

# %%
# concatenado_1 = interpolar_nans(concatenado_1, colunas_para_preencher=[
#     'G2_Gerador_Potência', 'G2_Oleo_Motor_Temp', 'G2_Oleo_Motor_Press',
#     'G2_Carga_Temperature', 'G2_Aumento_Pressão_Valvula_Real',
#     'G2_Gerador_Corrente_Média', 'G2_Gerador_Tensão_Média',
#     'G2_Gerador_Potência_Reativa', 'G2_Gerador_Potência_Aparente',
#     'G2_Gerador_frequencia', 'G2_Gerador_Fator_de_Potência',
#     'G2_Acelerador_Valv_Posição', 'G2_Jacket_Water_pressão',
#     'G2_Jacket_Water_Temp', 'G2_Cilindro_EX_GAS_TEMP_Média',
#     'g2_Turbocharger_Bypass_Posição', 'G2_Saída_Ativa_total',
#     'G2_Saída_Reativa_total', 'G2_LAMBDA_TECJET', 'G2_Gerador_Corrente_L1',
#     'G2_Gerador_Voltagem_L1_N', 'G2_Gerador_enrolamento_temp_L1',
#     'G2_Gerador_enrolamento_temp_L2', 'G2_Gerador_enrolamento_temp_L3',
#     'G2_Gerador_Extremidade_acionamento_rolamento',
#     'G2_Gerador_Bearing_nondriveend', 'G2_Gerador_Corrente_L2',
#     'G2_Gerador_Voltagem_L2_L3', 'G2_Gerador_Voltagem_L2_N',
#     'G2_Gerador_Corrente_N', 'G2_Excitação_Voltagem',
#     'G2_Gerador_Corrente_L3', 'G2_Gerador_Voltagem_L3_L1',
#     'G2_Gerador_Voltagem_L3_N'
# ])

# %% [markdown]
# ### DROPAR ID

# %%
# Dropar a coluna ID
concatenado_1 = concatenado_1.drop(columns=['ID'])

# %% [markdown]
# ### SALVAR O CONCATENADO

# %%
# Definir o caminho de saída
#caminho_saida_csv = r'C:\Users\MarioGoncalves\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_concatenados\files_29_01_and_02_04_concatenados_sem_NaNs.csv'
caminho_saida_pkl = r'H:\Path_Python\Dados_Python_2024\Lameirinho\Ficheiros_PKL_Saida\Arquivos_concatenados\files_29_01_and_20_05_concatenados_sem_NaNs.pkl'

# Salvar como CSV
#concatenado_1.to_csv(caminho_saida_csv, index=True)

# Salvar como pickle
concatenado_1.to_pickle(caminho_saida_pkl)
